# %% [markdown]
# # Advanced Exercise 1

# %% [markdown]
# # load modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # load fpkms.csv

# %%
df_fpkms = pd.read_csv( "../../qbb2020/data/fpkms.csv", index_col="t_name" )
df_fpkms
# Out:
#             gene_name    male_10    male_11    male_12    male_13   male_14A  \
# t_name
# FBtr0114258   CR41571   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0346770   CG45784   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0302440   CR12798   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0302347   CR40182  23.712564  11.967821  20.767498  13.566818  18.802116
# FBtr0346769   CG45783   0.000000   0.000000   0.000000   0.000000   0.000000
# ...               ...        ...        ...        ...        ...        ...
# FBtr0114187   CR40502   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0304147   CR40719   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0114216   CR40679   2.011199   0.000000   7.994137   2.064200   3.141665
# FBtr0114222   CR40743   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0114283   CR41619   0.000000   0.000000   0.000000   0.000000   0.000000
#
# ...

# %% [markdown]
# # subset transcript

# %%
goi = "FBtr0331261"

# %%
df_sxl = df_fpkms.loc[goi,:]
df_sxl
# Out:
# gene_name         Sxl
# male_10             0
# male_11             0
# male_12             0
# male_13             0
# male_14A            0
# male_14B            0
# male_14C            0
# male_14D      2.11732
# female_10           0
# female_11           0
# female_12           0
# female_13           0
# female_14A    46.0339
# female_14B    30.6056
# female_14C    38.9564
# female_14D    124.908
# Name: FBtr0331261, dtype: object

# %% [markdown]
# # Plot timeseries by sex

# %%
x = df_sxl[1:]
x
# Out:
# male_10             0
# male_11             0
# male_12             0
# male_13             0
# male_14A            0
# male_14B            0
# male_14C            0
# male_14D      2.11732
# female_10           0
# female_11           0
# female_12           0
# female_13           0
# female_14A    46.0339
# female_14B    30.6056
# female_14C    38.9564
# female_14D    124.908
# Name: FBtr0331261, dtype: object

# %%
age = ['10', '11', '12', '13', '14A', '14B', '14C', '14D']
fig, ax = plt.subplots()
ax.plot( age, x[0:8], label='male' )
ax.plot( age, x[8:], label='female' )
ax.set_title("Transcriptome FBtr0331261 of Drosophila Over Time per Sex")
ax.set_xlabel("Developmental Stage")
ax.set_ylabel("mRNA Abundance")
plt.legend()
plt.show()
